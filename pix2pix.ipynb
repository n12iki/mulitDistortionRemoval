# %% [markdown]
# # Colorful world - Google Colab interface
# *a pix2pix model to convert black&white images in colorful ones*

# %% [markdown]
# # Installation
# Steps to follow:
# 0. Check that you're using a GPU
# 1. Clone the repo
# 2. Install the dependencies
# 3. Download the data

# %% [markdown]
# ### Making the most of Colab free GPU:
# Click on execute -> modify execution type:
#
# <img src="./media/Colab1.png">
#
# Select GPU:
#
# <img src="./media/Colab2.png">

# %%
# %pwd

# %%
# !git clone https://username:pwd@github.com/SachaIZADI/colorful-world-pix2pix.git

# %%
# %cd colorful-world-pix2pix/

# %%
! pip install -r requirements.txt

# %%
# Download the data
# %cd colorful_world/data/

# %%
# !./download_data.sh

# %%
# %cd ..
# %cd ..

# %% [markdown]
# # Play with the model
# Play with the models, train your own, and make the most of Colab Free GPU

# %% [markdown]
# If you want to use checkpoints and save the model weights during training you can specify it with `train_on_colab=True` in the `Config` of the GAN. Weights will be saved in your own Google Drive. To do so you'll need to:
#
# 1. Create a folder at the root of your drive called "pix2pix"
# 2. Mount your drive by following the OAuth link that will appear on Colab and follow the instructions
#
# <img src="./media/OAuth_drive.png" width="750">

# %%
from colorful_world.config import Config
from colorful_world.models import cGANLoss

# %%
config = Config(
    lr_dis = 0.00000041,
    lr_gen = 0.0003,#0.00001,
    n_epochs = 300,
    batch_size = 1,
    save_frequency=10,
    train_dir = "C:/Users/n12i/Desktop/Building",
    prediction_dir = "C:/Users/n12i/Desktop/Building/results",
    model_dir = "./colorful_world/models/models_saved",
    picture_color_evolution = "C:/Users/n12i/Desktop/Building/results/ADE_train_00000555.jpg",
    result_dir = "./colorful_world/results",
    show_color_evolution = True,
    train_on_colab = False,
    save_every_epoch = True
)

print(config.gpu)
# Out:
# True

# %%
cgan = cGANLoss(config=config)

# %%
# %matplotlib notebook
cgan.train()
# Out:
# C:\Users\n12i\.conda\envs\torch\lib\site-packages\torch\nn\modules\loss.py:431: UserWarning: Using a target size (torch.Size([1, 1, 8, 8])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# data/samples\1train_input_.png
# data/samples\1train_groundtruth_.png
# Train - Discriminator Loss: 0.2495 Generator Loss: 2.0567
# C:\Users\n12i\Desktop\masterThesis\colorful-world-pix2pix-master4\colorful-world-pix2pix-master\colorful_world\models\c_ganLoss.py:370: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   tStructSim.append(measure.compare_ssim(predictions, labels,  multichannel=True))
# Saved Model
# C:\Users\n12i\Desktop\masterThesis\colorful-world-pix2pix-master4\colorful-world-pix2pix-master\colorful_world\models\c_ganLoss.py:437: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
#   sStructSim.append(measure.compare_ssim(predictions, labels,  multichannel=True))
# data/samples\1test_input_.png
# data/samples\1test_groundtruth_.png
# data/samples\2train_input_.png
# data/samples\2train_groundtruth_.png
# Train - Discriminator Loss: 0.2488 Generator Loss: 1.2876
# data/samples\2test_input_.png
# data/samples\2test_groundtruth_.png
# data/samples\3train_input_.png
# data/samples\3train_groundtruth_.png
# Train - Discriminator Loss: 0.2478 Generator Loss: 1.2738
# data/samples\3test_input_.png
# data/samples\3test_groundtruth_.png
# data/samples\4train_input_.png
# data/samples\4train_groundtruth_.png
# Train - Discriminator Loss: 0.2469 Generator Loss: 1.2026
# data/samples\4test_input_.png
# data/samples\4test_groundtruth_.png
# data/samples\5train_input_.png
# data/samples\5train_groundtruth_.png
# Train - Discriminator Loss: 0.2464 Generator Loss: 1.1091
# data/samples\5test_input_.png
# data/samples\5test_groundtruth_.png
# data/samples\6train_input_.png
# data/samples\6train_groundtruth_.png
# Train - Discriminator Loss: 0.2465 Generator Loss: 1.1444
# data/samples\6test_input_.png
# data/samples\6test_groundtruth_.png
# data/samples\7train_input_.png
# data/samples\7train_groundtruth_.png
# Train - Discriminator Loss: 0.2461 Generator Loss: 1.0781
# data/samples\7test_input_.png
# data/samples\7test_groundtruth_.png
# data/samples\8train_input_.png
# data/samples\8train_groundtruth_.png
# Train - Discriminator Loss: 0.2459 Generator Loss: 1.1152
# data/samples\8test_input_.png
# data/samples\8test_groundtruth_.png
# data/samples\9train_input_.png
# data/samples\9train_groundtruth_.png
# Train - Discriminator Loss: 0.2455 Generator Loss: 1.0127
# data/samples\9test_input_.png
# data/samples\9test_groundtruth_.png
# data/samples\10train_input_.png
# data/samples\10train_groundtruth_.png
# Train - Discriminator Loss: 0.2463 Generator Loss: 0.9512
# data/samples\10test_input_.png
# data/samples\10test_groundtruth_.png
# data/samples\11train_input_.png
# data/samples\11train_groundtruth_.png
# Train - Discriminator Loss: 0.2465 Generator Loss: 0.9179
# Saved Model
# data/samples\11test_input_.png
# data/samples\11test_groundtruth_.png
# data/samples\12train_input_.png
# data/samples\12train_groundtruth_.png
# Train - Discriminator Loss: 0.2472 Generator Loss: 0.8612
# data/samples\12test_input_.png
# data/samples\12test_groundtruth_.png
# data/samples\13train_input_.png
# data/samples\13train_groundtruth_.png
# Train - Discriminator Loss: 0.2464 Generator Loss: 0.8599
# data/samples\13test_input_.png
# data/samples\13test_groundtruth_.png
# data/samples\14train_input_.png
# data/samples\14train_groundtruth_.png
# Train - Discriminator Loss: 0.2457 Generator Loss: 0.8744
# data/samples\14test_input_.png
# data/samples\14test_groundtruth_.png
# data/samples\15train_input_.png
# data/samples\15train_groundtruth_.png
# Train - Discriminator Loss: 0.2479 Generator Loss: 0.8534
# data/samples\15test_input_.png
# data/samples\15test_groundtruth_.png
# data/samples\16train_input_.png
# data/samples\16train_groundtruth_.png
# Train - Discriminator Loss: 0.2479 Generator Loss: 0.8268
# data/samples\16test_input_.png
# data/samples\16test_groundtruth_.png
# data/samples\17train_input_.png
# data/samples\17train_groundtruth_.png
# Train - Discriminator Loss: 0.2474 Generator Loss: 0.8457
# data/samples\17test_input_.png
# data/samples\17test_groundtruth_.png
# data/samples\18train_input_.png
# data/samples\18train_groundtruth_.png
# Train - Discriminator Loss: 0.2480 Generator Loss: 0.8306
# data/samples\18test_input_.png
# data/samples\18test_groundtruth_.png
# data/samples\19train_input_.png
# data/samples\19train_groundtruth_.png
# Train - Discriminator Loss: 0.2481 Generator Loss: 0.8422
# data/samples\19test_input_.png
# data/samples\19test_groundtruth_.png
# data/samples\20train_input_.png
# data/samples\20train_groundtruth_.png
# Train - Discriminator Loss: 0.2483 Generator Loss: 0.8050
# data/samples\20test_input_.png
# data/samples\20test_groundtruth_.png
# data/samples\21train_input_.png
# data/samples\21train_groundtruth_.png
# Train - Discriminator Loss: 0.2480 Generator Loss: 0.8294
# Saved Model
# data/samples\21test_input_.png
# data/samples\21test_groundtruth_.png
# data/samples\22train_input_.png
# data/samples\22train_groundtruth_.png
# Train - Discriminator Loss: 0.2488 Generator Loss: 0.7720
# data/samples\22test_input_.png
# data/samples\22test_groundtruth_.png
# data/samples\23train_input_.png
# data/samples\23train_groundtruth_.png
# Train - Discriminator Loss: 0.2476 Generator Loss: 0.7770
# data/samples\23test_input_.png
# data/samples\23test_groundtruth_.png
# data/samples\24train_input_.png
# data/samples\24train_groundtruth_.png
# Train - Discriminator Loss: 0.2472 Generator Loss: 0.7393
# data/samples\24test_input_.png
# data/samples\24test_groundtruth_.png
# data/samples\25train_input_.png
# data/samples\25train_groundtruth_.png
# Train - Discriminator Loss: 0.2474 Generator Loss: 0.7161
# data/samples\25test_input_.png
# data/samples\25test_groundtruth_.png
# data/samples\26train_input_.png
# data/samples\26train_groundtruth_.png
# Train - Discriminator Loss: 0.2470 Generator Loss: 0.7048
# data/samples\26test_input_.png
# data/samples\26test_groundtruth_.png
# data/samples\27train_input_.png
# data/samples\27train_groundtruth_.png
# Train - Discriminator Loss: 0.2462 Generator Loss: 0.7200
# data/samples\27test_input_.png
# data/samples\27test_groundtruth_.png
# data/samples\28train_input_.png
# data/samples\28train_groundtruth_.png
# Train - Discriminator Loss: 0.2456 Generator Loss: 0.6793
# data/samples\28test_input_.png
# data/samples\28test_groundtruth_.png
# data/samples\29train_input_.png
# data/samples\29train_groundtruth_.png
# Train - Discriminator Loss: 0.2456 Generator Loss: 0.7094
# data/samples\29test_input_.png
# data/samples\29test_groundtruth_.png
# data/samples\30train_input_.png
# data/samples\30train_groundtruth_.png
# Train - Discriminator Loss: 0.2451 Generator Loss: 0.6628
# data/samples\30test_input_.png
# data/samples\30test_groundtruth_.png
# data/samples\31train_input_.png
# data/samples\31train_groundtruth_.png
# Train - Discriminator Loss: 0.2448 Generator Loss: 0.6840
# Saved Model
# data/samples\31test_input_.png
# data/samples\31test_groundtruth_.png
# data/samples\32train_input_.png
# data/samples\32train_groundtruth_.png
# Train - Discriminator Loss: 0.2445 Generator Loss: 0.6664
# data/samples\32test_input_.png
# data/samples\32test_groundtruth_.png
# data/samples\33train_input_.png
# data/samples\33train_groundtruth_.png
# Train - Discriminator Loss: 0.2442 Generator Loss: 0.6913
# data/samples\33test_input_.png
# data/samples\33test_groundtruth_.png
# data/samples\34train_input_.png
# data/samples\34train_groundtruth_.png
# Train - Discriminator Loss: 0.2425 Generator Loss: 0.6842
# data/samples\34test_input_.png
# data/samples\34test_groundtruth_.png
# data/samples\35train_input_.png
# data/samples\35train_groundtruth_.png
# Train - Discriminator Loss: 0.2436 Generator Loss: 0.6558
# data/samples\35test_input_.png
# data/samples\35test_groundtruth_.png
# data/samples\36train_input_.png
# data/samples\36train_groundtruth_.png
# Train - Discriminator Loss: 0.2437 Generator Loss: 0.6755
# data/samples\36test_input_.png
# data/samples\36test_groundtruth_.png
# data/samples\37train_input_.png
# data/samples\37train_groundtruth_.png
# Train - Discriminator Loss: 0.2424 Generator Loss: 0.6644
# data/samples\37test_input_.png
# data/samples\37test_groundtruth_.png
# data/samples\38train_input_.png
# data/samples\38train_groundtruth_.png
# Train - Discriminator Loss: 0.2420 Generator Loss: 0.6448
# data/samples\38test_input_.png
# data/samples\38test_groundtruth_.png
# data/samples\39train_input_.png
# data/samples\39train_groundtruth_.png
# Train - Discriminator Loss: 0.2427 Generator Loss: 0.6221
# data/samples\39test_input_.png
# data/samples\39test_groundtruth_.png
# data/samples\40train_input_.png
# data/samples\40train_groundtruth_.png
# Train - Discriminator Loss: 0.2405 Generator Loss: 0.6412
# data/samples\40test_input_.png
# data/samples\40test_groundtruth_.png
# data/samples\41train_input_.png
# data/samples\41train_groundtruth_.png
# Train - Discriminator Loss: 0.2405 Generator Loss: 0.6506
# Saved Model
# data/samples\41test_input_.png
# data/samples\41test_groundtruth_.png
# data/samples\42train_input_.png
# data/samples\42train_groundtruth_.png
# Train - Discriminator Loss: 0.2401 Generator Loss: 0.6459
# data/samples\42test_input_.png
# data/samples\42test_groundtruth_.png
# data/samples\43train_input_.png
# data/samples\43train_groundtruth_.png
# Train - Discriminator Loss: 0.2392 Generator Loss: 0.6638
# data/samples\43test_input_.png
# data/samples\43test_groundtruth_.png
# data/samples\44train_input_.png
# data/samples\44train_groundtruth_.png
# Train - Discriminator Loss: 0.2394 Generator Loss: 0.6272
# data/samples\44test_input_.png
# data/samples\44test_groundtruth_.png
# data/samples\45train_input_.png
# data/samples\45train_groundtruth_.png
# Train - Discriminator Loss: 0.2381 Generator Loss: 0.6491
# data/samples\45test_input_.png
# data/samples\45test_groundtruth_.png
# data/samples\46train_input_.png
# data/samples\46train_groundtruth_.png
# Train - Discriminator Loss: 0.2367 Generator Loss: 0.6419
# data/samples\46test_input_.png
# data/samples\46test_groundtruth_.png
# data/samples\47train_input_.png
# data/samples\47train_groundtruth_.png
# Train - Discriminator Loss: 0.2382 Generator Loss: 0.6383
# data/samples\47test_input_.png
# data/samples\47test_groundtruth_.png
# data/samples\48train_input_.png
# data/samples\48train_groundtruth_.png
# Train - Discriminator Loss: 0.2366 Generator Loss: 0.6364
# data/samples\48test_input_.png
# data/samples\48test_groundtruth_.png
# data/samples\49train_input_.png
# data/samples\49train_groundtruth_.png
# Train - Discriminator Loss: 0.2368 Generator Loss: 0.6110
# data/samples\49test_input_.png
# data/samples\49test_groundtruth_.png
# data/samples\50train_input_.png
# data/samples\50train_groundtruth_.png
# Train - Discriminator Loss: 0.2350 Generator Loss: 0.6485
# data/samples\50test_input_.png
# data/samples\50test_groundtruth_.png
# data/samples\51train_input_.png
# data/samples\51train_groundtruth_.png
# Train - Discriminator Loss: 0.2352 Generator Loss: 0.6318
# Saved Model
# data/samples\51test_input_.png
# data/samples\51test_groundtruth_.png
# data/samples\52train_input_.png
# data/samples\52train_groundtruth_.png
# Train - Discriminator Loss: 0.2378 Generator Loss: 0.6082
# data/samples\52test_input_.png
# data/samples\52test_groundtruth_.png
# data/samples\53train_input_.png
# data/samples\53train_groundtruth_.png
# Train - Discriminator Loss: 0.2343 Generator Loss: 0.6185
# data/samples\53test_input_.png
# data/samples\53test_groundtruth_.png
# data/samples\54train_input_.png
# data/samples\54train_groundtruth_.png
# Train - Discriminator Loss: 0.2353 Generator Loss: 0.6111
# data/samples\54test_input_.png
# data/samples\54test_groundtruth_.png
# data/samples\55train_input_.png
# data/samples\55train_groundtruth_.png
# Train - Discriminator Loss: 0.2331 Generator Loss: 0.6094
# data/samples\55test_input_.png
# data/samples\55test_groundtruth_.png
# data/samples\56train_input_.png
# data/samples\56train_groundtruth_.png
# Train - Discriminator Loss: 0.2327 Generator Loss: 0.6161
# data/samples\56test_input_.png
# data/samples\56test_groundtruth_.png
# data/samples\57train_input_.png
# data/samples\57train_groundtruth_.png
# Train - Discriminator Loss: 0.2332 Generator Loss: 0.6178
# data/samples\57test_input_.png
# data/samples\57test_groundtruth_.png
# data/samples\58train_input_.png
# data/samples\58train_groundtruth_.png
# Train - Discriminator Loss: 0.2329 Generator Loss: 0.6135
# data/samples\58test_input_.png
# data/samples\58test_groundtruth_.png
# data/samples\59train_input_.png
# data/samples\59train_groundtruth_.png
# Train - Discriminator Loss: 0.2317 Generator Loss: 0.6153
# data/samples\59test_input_.png
# data/samples\59test_groundtruth_.png
# data/samples\60train_input_.png
# data/samples\60train_groundtruth_.png
# Train - Discriminator Loss: 0.2296 Generator Loss: 0.6168
# data/samples\60test_input_.png
# data/samples\60test_groundtruth_.png
# data/samples\61train_input_.png
# data/samples\61train_groundtruth_.png
# Train - Discriminator Loss: 0.2292 Generator Loss: 0.6218
# Saved Model
# data/samples\61test_input_.png
# data/samples\61test_groundtruth_.png
# data/samples\62train_input_.png
# data/samples\62train_groundtruth_.png
# Train - Discriminator Loss: 0.2288 Generator Loss: 0.6026
# data/samples\62test_input_.png
# data/samples\62test_groundtruth_.png
# data/samples\63train_input_.png
# data/samples\63train_groundtruth_.png
# Train - Discriminator Loss: 0.2283 Generator Loss: 0.6342
# data/samples\63test_input_.png
# data/samples\63test_groundtruth_.png
# data/samples\64train_input_.png
# data/samples\64train_groundtruth_.png
# Train - Discriminator Loss: 0.2285 Generator Loss: 0.6120
# data/samples\64test_input_.png
# data/samples\64test_groundtruth_.png
# data/samples\65train_input_.png
# data/samples\65train_groundtruth_.png
# Train - Discriminator Loss: 0.2292 Generator Loss: 0.5895
# data/samples\65test_input_.png
# data/samples\65test_groundtruth_.png
# data/samples\66train_input_.png
# data/samples\66train_groundtruth_.png
# Train - Discriminator Loss: 0.2254 Generator Loss: 0.6355
# data/samples\66test_input_.png
# data/samples\66test_groundtruth_.png
# data/samples\67train_input_.png
# data/samples\67train_groundtruth_.png
# Train - Discriminator Loss: 0.2274 Generator Loss: 0.6072
# data/samples\67test_input_.png
# data/samples\67test_groundtruth_.png
# data/samples\68train_input_.png
# data/samples\68train_groundtruth_.png
# Train - Discriminator Loss: 0.2272 Generator Loss: 0.6100
# data/samples\68test_input_.png
# data/samples\68test_groundtruth_.png
# data/samples\69train_input_.png
# data/samples\69train_groundtruth_.png
# Train - Discriminator Loss: 0.2250 Generator Loss: 0.5941
# data/samples\69test_input_.png
# data/samples\69test_groundtruth_.png
# data/samples\70train_input_.png
# data/samples\70train_groundtruth_.png
# Train - Discriminator Loss: 0.2255 Generator Loss: 0.6012
# data/samples\70test_input_.png
# data/samples\70test_groundtruth_.png
# data/samples\71train_input_.png
# data/samples\71train_groundtruth_.png
# Train - Discriminator Loss: 0.2219 Generator Loss: 0.6209
# Saved Model
# data/samples\71test_input_.png
# data/samples\71test_groundtruth_.png
# data/samples\72train_input_.png
# data/samples\72train_groundtruth_.png
# Train - Discriminator Loss: 0.2240 Generator Loss: 0.6092
# data/samples\72test_input_.png
# data/samples\72test_groundtruth_.png
# data/samples\73train_input_.png
# data/samples\73train_groundtruth_.png
# Train - Discriminator Loss: 0.2227 Generator Loss: 0.5931
# data/samples\73test_input_.png
# data/samples\73test_groundtruth_.png
# data/samples\74train_input_.png
# data/samples\74train_groundtruth_.png
# Train - Discriminator Loss: 0.2217 Generator Loss: 0.6060
# data/samples\74test_input_.png
# data/samples\74test_groundtruth_.png
# data/samples\75train_input_.png
# data/samples\75train_groundtruth_.png
# Train - Discriminator Loss: 0.2210 Generator Loss: 0.6303
# data/samples\75test_input_.png
# data/samples\75test_groundtruth_.png
# data/samples\76train_input_.png
# data/samples\76train_groundtruth_.png
# Train - Discriminator Loss: 0.2205 Generator Loss: 0.6259
# data/samples\76test_input_.png
# data/samples\76test_groundtruth_.png
# data/samples\77train_input_.png
# data/samples\77train_groundtruth_.png
# Train - Discriminator Loss: 0.2184 Generator Loss: 0.6119
# data/samples\77test_input_.png
# data/samples\77test_groundtruth_.png
# data/samples\78train_input_.png
# data/samples\78train_groundtruth_.png
# Train - Discriminator Loss: 0.2208 Generator Loss: 0.6003
# data/samples\78test_input_.png
# data/samples\78test_groundtruth_.png
# data/samples\79train_input_.png
# data/samples\79train_groundtruth_.png
# Train - Discriminator Loss: 0.2205 Generator Loss: 0.5969
# data/samples\79test_input_.png
# data/samples\79test_groundtruth_.png
# data/samples\80train_input_.png
# data/samples\80train_groundtruth_.png
# Train - Discriminator Loss: 0.2210 Generator Loss: 0.6060
# data/samples\80test_input_.png
# data/samples\80test_groundtruth_.png
# data/samples\81train_input_.png
# data/samples\81train_groundtruth_.png
# Train - Discriminator Loss: 0.2193 Generator Loss: 0.5970
# Saved Model
# data/samples\81test_input_.png
# data/samples\81test_groundtruth_.png
# data/samples\82train_input_.png
# data/samples\82train_groundtruth_.png
# Train - Discriminator Loss: 0.2189 Generator Loss: 0.6187
# data/samples\82test_input_.png
# data/samples\82test_groundtruth_.png
# data/samples\83train_input_.png
# data/samples\83train_groundtruth_.png
# Train - Discriminator Loss: 0.2224 Generator Loss: 0.5953
# data/samples\83test_input_.png
# data/samples\83test_groundtruth_.png
# data/samples\84train_input_.png
# data/samples\84train_groundtruth_.png
# Train - Discriminator Loss: 0.2197 Generator Loss: 0.5963
# data/samples\84test_input_.png
# data/samples\84test_groundtruth_.png
# data/samples\85train_input_.png
# data/samples\85train_groundtruth_.png
# Train - Discriminator Loss: 0.2172 Generator Loss: 0.6050
# data/samples\85test_input_.png
# data/samples\85test_groundtruth_.png
# data/samples\86train_input_.png
# data/samples\86train_groundtruth_.png
# Train - Discriminator Loss: 0.2169 Generator Loss: 0.6047
# data/samples\86test_input_.png
# data/samples\86test_groundtruth_.png
# data/samples\87train_input_.png
# data/samples\87train_groundtruth_.png
# Train - Discriminator Loss: 0.2160 Generator Loss: 0.6132
# data/samples\87test_input_.png
# data/samples\87test_groundtruth_.png
# data/samples\88train_input_.png
# data/samples\88train_groundtruth_.png
# Train - Discriminator Loss: 0.2159 Generator Loss: 0.6145
# data/samples\88test_input_.png
# data/samples\88test_groundtruth_.png
# data/samples\89train_input_.png
# data/samples\89train_groundtruth_.png
# Train - Discriminator Loss: 0.2137 Generator Loss: 0.6080
# data/samples\89test_input_.png
# data/samples\89test_groundtruth_.png
# data/samples\90train_input_.png
# data/samples\90train_groundtruth_.png
# Train - Discriminator Loss: 0.2123 Generator Loss: 0.6000
# data/samples\90test_input_.png
# data/samples\90test_groundtruth_.png
# data/samples\91train_input_.png
# data/samples\91train_groundtruth_.png
# Train - Discriminator Loss: 0.2072 Generator Loss: 0.6156
# Saved Model
# data/samples\91test_input_.png
# data/samples\91test_groundtruth_.png
# data/samples\92train_input_.png
# data/samples\92train_groundtruth_.png
# Train - Discriminator Loss: 0.2104 Generator Loss: 0.6057
# data/samples\92test_input_.png
# data/samples\92test_groundtruth_.png
# data/samples\93train_input_.png
# data/samples\93train_groundtruth_.png
# Train - Discriminator Loss: 0.2089 Generator Loss: 0.6166
# data/samples\93test_input_.png
# data/samples\93test_groundtruth_.png
# data/samples\94train_input_.png
# data/samples\94train_groundtruth_.png
# Train - Discriminator Loss: 0.2091 Generator Loss: 0.6202
# data/samples\94test_input_.png
# data/samples\94test_groundtruth_.png
# data/samples\95train_input_.png
# data/samples\95train_groundtruth_.png
# Train - Discriminator Loss: 0.2086 Generator Loss: 0.6136
# data/samples\95test_input_.png
# data/samples\95test_groundtruth_.png
# data/samples\96train_input_.png
# data/samples\96train_groundtruth_.png
# Train - Discriminator Loss: 0.2064 Generator Loss: 0.6140
# data/samples\96test_input_.png
# data/samples\96test_groundtruth_.png
# data/samples\97train_input_.png
# data/samples\97train_groundtruth_.png
# Train - Discriminator Loss: 0.2036 Generator Loss: 0.6255
# data/samples\97test_input_.png
# data/samples\97test_groundtruth_.png
# data/samples\98train_input_.png
# data/samples\98train_groundtruth_.png
# Train - Discriminator Loss: 0.2037 Generator Loss: 0.6280
# data/samples\98test_input_.png
# data/samples\98test_groundtruth_.png
# data/samples\99train_input_.png
# data/samples\99train_groundtruth_.png
# Train - Discriminator Loss: 0.2005 Generator Loss: 0.6373
# data/samples\99test_input_.png
# data/samples\99test_groundtruth_.png
# data/samples\100train_input_.png
# data/samples\100train_groundtruth_.png
# Train - Discriminator Loss: 0.2003 Generator Loss: 0.6165
# data/samples\100test_input_.png
# data/samples\100test_groundtruth_.png
# data/samples\101train_input_.png
# data/samples\101train_groundtruth_.png
# Train - Discriminator Loss: 0.2018 Generator Loss: 0.6361
# Saved Model
# data/samples\101test_input_.png
# data/samples\101test_groundtruth_.png
# data/samples\102train_input_.png
# data/samples\102train_groundtruth_.png
# Train - Discriminator Loss: 0.2034 Generator Loss: 0.6235
# data/samples\102test_input_.png
# data/samples\102test_groundtruth_.png
# data/samples\103train_input_.png
# data/samples\103train_groundtruth_.png
# Train - Discriminator Loss: 0.2039 Generator Loss: 0.6209
# data/samples\103test_input_.png
# data/samples\103test_groundtruth_.png
# data/samples\104train_input_.png
# data/samples\104train_groundtruth_.png
# Train - Discriminator Loss: 0.2014 Generator Loss: 0.6323
# data/samples\104test_input_.png
# data/samples\104test_groundtruth_.png
# data/samples\105train_input_.png
# data/samples\105train_groundtruth_.png
# Train - Discriminator Loss: 0.2035 Generator Loss: 0.6239
# data/samples\105test_input_.png
# data/samples\105test_groundtruth_.png
# data/samples\106train_input_.png
# data/samples\106train_groundtruth_.png
# Train - Discriminator Loss: 0.2002 Generator Loss: 0.6374
# data/samples\106test_input_.png
# data/samples\106test_groundtruth_.png
# data/samples\107train_input_.png
# data/samples\107train_groundtruth_.png
# Train - Discriminator Loss: 0.1995 Generator Loss: 0.6322
# data/samples\107test_input_.png
# data/samples\107test_groundtruth_.png
# data/samples\108train_input_.png
# data/samples\108train_groundtruth_.png
# Train - Discriminator Loss: 0.1949 Generator Loss: 0.6476
# data/samples\108test_input_.png
# data/samples\108test_groundtruth_.png
# data/samples\109train_input_.png
# data/samples\109train_groundtruth_.png
# Train - Discriminator Loss: 0.1924 Generator Loss: 0.6519
# data/samples\109test_input_.png
# data/samples\109test_groundtruth_.png
# data/samples\110train_input_.png
# data/samples\110train_groundtruth_.png
# Train - Discriminator Loss: 0.1923 Generator Loss: 0.6504
# data/samples\110test_input_.png
# data/samples\110test_groundtruth_.png
# data/samples\111train_input_.png
# data/samples\111train_groundtruth_.png
# Train - Discriminator Loss: 0.1892 Generator Loss: 0.6575
# Saved Model
# data/samples\111test_input_.png
# data/samples\111test_groundtruth_.png
# data/samples\112train_input_.png
# data/samples\112train_groundtruth_.png
# Train - Discriminator Loss: 0.1883 Generator Loss: 0.6644
# data/samples\112test_input_.png
# data/samples\112test_groundtruth_.png
# data/samples\113train_input_.png
# data/samples\113train_groundtruth_.png
# Train - Discriminator Loss: 0.1855 Generator Loss: 0.6587
# data/samples\113test_input_.png
# data/samples\113test_groundtruth_.png
# data/samples\114train_input_.png
# data/samples\114train_groundtruth_.png
# Train - Discriminator Loss: 0.1816 Generator Loss: 0.6916
# data/samples\114test_input_.png
# data/samples\114test_groundtruth_.png
# data/samples\115train_input_.png
# data/samples\115train_groundtruth_.png
# Train - Discriminator Loss: 0.1806 Generator Loss: 0.6749
# data/samples\115test_input_.png
# data/samples\115test_groundtruth_.png
# data/samples\116train_input_.png
# data/samples\116train_groundtruth_.png
# Train - Discriminator Loss: 0.1779 Generator Loss: 0.7097
# data/samples\116test_input_.png
# data/samples\116test_groundtruth_.png
# data/samples\117train_input_.png
# data/samples\117train_groundtruth_.png
# Train - Discriminator Loss: 0.1752 Generator Loss: 0.6914
# data/samples\117test_input_.png
# data/samples\117test_groundtruth_.png
# data/samples\118train_input_.png
# data/samples\118train_groundtruth_.png
# Train - Discriminator Loss: 0.1720 Generator Loss: 0.7091
# data/samples\118test_input_.png
# data/samples\118test_groundtruth_.png
# data/samples\119train_input_.png
# data/samples\119train_groundtruth_.png
# Train - Discriminator Loss: 0.1706 Generator Loss: 0.7060
# data/samples\119test_input_.png
# data/samples\119test_groundtruth_.png
# data/samples\120train_input_.png
# data/samples\120train_groundtruth_.png
# Train - Discriminator Loss: 0.1669 Generator Loss: 0.7228
# data/samples\120test_input_.png
# data/samples\120test_groundtruth_.png
# data/samples\121train_input_.png
# data/samples\121train_groundtruth_.png
# Train - Discriminator Loss: 0.1646 Generator Loss: 0.7285
# Saved Model
# data/samples\121test_input_.png
# data/samples\121test_groundtruth_.png
# data/samples\122train_input_.png
# data/samples\122train_groundtruth_.png
# Train - Discriminator Loss: 0.1621 Generator Loss: 0.7374
# data/samples\122test_input_.png
# data/samples\122test_groundtruth_.png
# data/samples\123train_input_.png
# data/samples\123train_groundtruth_.png
# Train - Discriminator Loss: 0.1602 Generator Loss: 0.7359
# data/samples\123test_input_.png
# data/samples\123test_groundtruth_.png
# data/samples\124train_input_.png
# data/samples\124train_groundtruth_.png
# Train - Discriminator Loss: 0.1563 Generator Loss: 0.7576
# data/samples\124test_input_.png
# data/samples\124test_groundtruth_.png
# data/samples\125train_input_.png
# data/samples\125train_groundtruth_.png
# Train - Discriminator Loss: 0.1534 Generator Loss: 0.7507
# data/samples\125test_input_.png
# data/samples\125test_groundtruth_.png
# data/samples\126train_input_.png
# data/samples\126train_groundtruth_.png
# Train - Discriminator Loss: 0.1526 Generator Loss: 0.7839
# data/samples\126test_input_.png
# data/samples\126test_groundtruth_.png
# data/samples\127train_input_.png
# data/samples\127train_groundtruth_.png
# Train - Discriminator Loss: 0.1495 Generator Loss: 0.7706
# data/samples\127test_input_.png
# data/samples\127test_groundtruth_.png
# data/samples\128train_input_.png
# data/samples\128train_groundtruth_.png
# Train - Discriminator Loss: 0.1458 Generator Loss: 0.8027
# data/samples\128test_input_.png
# data/samples\128test_groundtruth_.png
# data/samples\129train_input_.png
# data/samples\129train_groundtruth_.png
# Train - Discriminator Loss: 0.1429 Generator Loss: 0.8128
# data/samples\129test_input_.png
# data/samples\129test_groundtruth_.png
# data/samples\130train_input_.png
# data/samples\130train_groundtruth_.png
# Train - Discriminator Loss: 0.1425 Generator Loss: 0.8142
# data/samples\130test_input_.png
# data/samples\130test_groundtruth_.png
# data/samples\131train_input_.png
# data/samples\131train_groundtruth_.png
# Train - Discriminator Loss: 0.1375 Generator Loss: 0.8584
# Saved Model
# data/samples\131test_input_.png
# data/samples\131test_groundtruth_.png
# data/samples\132train_input_.png
# data/samples\132train_groundtruth_.png
# Train - Discriminator Loss: 0.1366 Generator Loss: 0.8361
# data/samples\132test_input_.png
# data/samples\132test_groundtruth_.png
# data/samples\133train_input_.png
# data/samples\133train_groundtruth_.png
# Train - Discriminator Loss: 0.1325 Generator Loss: 0.8884
# data/samples\133test_input_.png
# data/samples\133test_groundtruth_.png
# data/samples\134train_input_.png
# data/samples\134train_groundtruth_.png
# Train - Discriminator Loss: 0.1311 Generator Loss: 0.8722
# data/samples\134test_input_.png
# data/samples\134test_groundtruth_.png
# data/samples\135train_input_.png
# data/samples\135train_groundtruth_.png
# Train - Discriminator Loss: 0.1290 Generator Loss: 0.8847
# data/samples\135test_input_.png
# data/samples\135test_groundtruth_.png
# data/samples\136train_input_.png
# data/samples\136train_groundtruth_.png
# Train - Discriminator Loss: 0.1273 Generator Loss: 0.9050
# data/samples\136test_input_.png
# data/samples\136test_groundtruth_.png
# data/samples\137train_input_.png
# data/samples\137train_groundtruth_.png
# Train - Discriminator Loss: 0.1243 Generator Loss: 0.9214
# data/samples\137test_input_.png
# data/samples\137test_groundtruth_.png
# data/samples\138train_input_.png
# data/samples\138train_groundtruth_.png
# Train - Discriminator Loss: 0.1228 Generator Loss: 0.9291
# data/samples\138test_input_.png
# data/samples\138test_groundtruth_.png
# data/samples\139train_input_.png
# data/samples\139train_groundtruth_.png
# Train - Discriminator Loss: 0.1217 Generator Loss: 0.9507
# data/samples\139test_input_.png
# data/samples\139test_groundtruth_.png
# data/samples\140train_input_.png
# data/samples\140train_groundtruth_.png
# Train - Discriminator Loss: 0.1202 Generator Loss: 0.9486
# data/samples\140test_input_.png
# data/samples\140test_groundtruth_.png
# data/samples\141train_input_.png
# data/samples\141train_groundtruth_.png
# Train - Discriminator Loss: 0.1185 Generator Loss: 0.9630
# Saved Model
# data/samples\141test_input_.png
# data/samples\141test_groundtruth_.png
# data/samples\142train_input_.png
# data/samples\142train_groundtruth_.png
# Train - Discriminator Loss: 0.1165 Generator Loss: 0.9837
# data/samples\142test_input_.png
# data/samples\142test_groundtruth_.png
# data/samples\143train_input_.png
# data/samples\143train_groundtruth_.png
# Train - Discriminator Loss: 0.1155 Generator Loss: 0.9771
# data/samples\143test_input_.png
# data/samples\143test_groundtruth_.png
# data/samples\144train_input_.png
# data/samples\144train_groundtruth_.png
# Train - Discriminator Loss: 0.1137 Generator Loss: 0.9943
# data/samples\144test_input_.png
# data/samples\144test_groundtruth_.png
# data/samples\145train_input_.png
# data/samples\145train_groundtruth_.png
# Train - Discriminator Loss: 0.1125 Generator Loss: 1.0192
# data/samples\145test_input_.png
# data/samples\145test_groundtruth_.png
# data/samples\146train_input_.png
# data/samples\146train_groundtruth_.png
# Train - Discriminator Loss: 0.1117 Generator Loss: 1.0183
# data/samples\146test_input_.png
# data/samples\146test_groundtruth_.png
# data/samples\147train_input_.png
# data/samples\147train_groundtruth_.png
# Train - Discriminator Loss: 0.1100 Generator Loss: 1.0344
# data/samples\147test_input_.png
# data/samples\147test_groundtruth_.png
# data/samples\148train_input_.png
# data/samples\148train_groundtruth_.png
# Train - Discriminator Loss: 0.1106 Generator Loss: 1.0154
# data/samples\148test_input_.png
# data/samples\148test_groundtruth_.png
# data/samples\149train_input_.png
# data/samples\149train_groundtruth_.png
# Train - Discriminator Loss: 0.1084 Generator Loss: 1.0415
# data/samples\149test_input_.png
# data/samples\149test_groundtruth_.png
# data/samples\150train_input_.png
# data/samples\150train_groundtruth_.png
# Train - Discriminator Loss: 0.1089 Generator Loss: 1.0393
# data/samples\150test_input_.png
# data/samples\150test_groundtruth_.png
# data/samples\151train_input_.png
# data/samples\151train_groundtruth_.png
# Train - Discriminator Loss: 0.1069 Generator Loss: 1.0655
# Saved Model
# data/samples\151test_input_.png
# data/samples\151test_groundtruth_.png
# data/samples\152train_input_.png
# data/samples\152train_groundtruth_.png
# Train - Discriminator Loss: 0.1071 Generator Loss: 1.0510
# data/samples\152test_input_.png
# data/samples\152test_groundtruth_.png
# data/samples\153train_input_.png
# data/samples\153train_groundtruth_.png
# Train - Discriminator Loss: 0.1075 Generator Loss: 1.0500
# data/samples\153test_input_.png
# data/samples\153test_groundtruth_.png
# data/samples\154train_input_.png
# data/samples\154train_groundtruth_.png
# Train - Discriminator Loss: 0.1055 Generator Loss: 1.0679
# data/samples\154test_input_.png
# data/samples\154test_groundtruth_.png
# data/samples\155train_input_.png
# data/samples\155train_groundtruth_.png
# Train - Discriminator Loss: 0.1050 Generator Loss: 1.0756
# data/samples\155test_input_.png
# data/samples\155test_groundtruth_.png
# data/samples\156train_input_.png
# data/samples\156train_groundtruth_.png
# Train - Discriminator Loss: 0.1038 Generator Loss: 1.0773
# data/samples\156test_input_.png
# data/samples\156test_groundtruth_.png
# data/samples\157train_input_.png
# data/samples\157train_groundtruth_.png
# Train - Discriminator Loss: 0.1042 Generator Loss: 1.0980
# data/samples\157test_input_.png
# data/samples\157test_groundtruth_.png
# data/samples\158train_input_.png
# data/samples\158train_groundtruth_.png
# Train - Discriminator Loss: 0.1034 Generator Loss: 1.0849
# data/samples\158test_input_.png
# data/samples\158test_groundtruth_.png
# data/samples\159train_input_.png
# data/samples\159train_groundtruth_.png
# Train - Discriminator Loss: 0.1024 Generator Loss: 1.0909
# data/samples\159test_input_.png
# data/samples\159test_groundtruth_.png
# data/samples\160train_input_.png
# data/samples\160train_groundtruth_.png
# Train - Discriminator Loss: 0.1012 Generator Loss: 1.1078
# data/samples\160test_input_.png
# data/samples\160test_groundtruth_.png
# data/samples\161train_input_.png
# data/samples\161train_groundtruth_.png
# Train - Discriminator Loss: 0.0989 Generator Loss: 1.0977
# Saved Model
# data/samples\161test_input_.png
# data/samples\161test_groundtruth_.png
# data/samples\162train_input_.png
# data/samples\162train_groundtruth_.png
# Train - Discriminator Loss: 0.0971 Generator Loss: 1.0986
# data/samples\162test_input_.png
# data/samples\162test_groundtruth_.png
# data/samples\163train_input_.png
# data/samples\163train_groundtruth_.png
# Train - Discriminator Loss: 0.0960 Generator Loss: 1.0729
# data/samples\163test_input_.png
# data/samples\163test_groundtruth_.png
# data/samples\164train_input_.png
# data/samples\164train_groundtruth_.png
# Train - Discriminator Loss: 0.0927 Generator Loss: 1.1035
# data/samples\164test_input_.png
# data/samples\164test_groundtruth_.png
# data/samples\165train_input_.png
# data/samples\165train_groundtruth_.png
# Train - Discriminator Loss: 0.0915 Generator Loss: 1.0977
# data/samples\165test_input_.png
# data/samples\165test_groundtruth_.png
# data/samples\166train_input_.png
# data/samples\166train_groundtruth_.png
# Train - Discriminator Loss: 0.0911 Generator Loss: 1.1083
# data/samples\166test_input_.png
# data/samples\166test_groundtruth_.png
# data/samples\167train_input_.png
# data/samples\167train_groundtruth_.png
# Train - Discriminator Loss: 0.0889 Generator Loss: 1.1069
# data/samples\167test_input_.png
# data/samples\167test_groundtruth_.png
# data/samples\168train_input_.png
# data/samples\168train_groundtruth_.png
# Train - Discriminator Loss: 0.0875 Generator Loss: 1.1044
# data/samples\168test_input_.png
# data/samples\168test_groundtruth_.png
# data/samples\169train_input_.png
# data/samples\169train_groundtruth_.png
# Train - Discriminator Loss: 0.0864 Generator Loss: 1.1128
# data/samples\169test_input_.png
# data/samples\169test_groundtruth_.png
# data/samples\170train_input_.png
# data/samples\170train_groundtruth_.png
# Train - Discriminator Loss: 0.0857 Generator Loss: 1.1231
# data/samples\170test_input_.png
# data/samples\170test_groundtruth_.png
# data/samples\171train_input_.png
# data/samples\171train_groundtruth_.png
# Train - Discriminator Loss: 0.0849 Generator Loss: 1.1052
# Saved Model
# data/samples\171test_input_.png
# data/samples\171test_groundtruth_.png
# data/samples\172train_input_.png
# data/samples\172train_groundtruth_.png
# Train - Discriminator Loss: 0.0831 Generator Loss: 1.1199
# data/samples\172test_input_.png
# data/samples\172test_groundtruth_.png
# data/samples\173train_input_.png
# data/samples\173train_groundtruth_.png
# Train - Discriminator Loss: 0.0817 Generator Loss: 1.1365
# data/samples\173test_input_.png
# data/samples\173test_groundtruth_.png
# data/samples\174train_input_.png
# data/samples\174train_groundtruth_.png
# Train - Discriminator Loss: 0.0813 Generator Loss: 1.1180
# data/samples\174test_input_.png
# data/samples\174test_groundtruth_.png
# data/samples\175train_input_.png
# data/samples\175train_groundtruth_.png
# Train - Discriminator Loss: 0.0787 Generator Loss: 1.1170
# data/samples\175test_input_.png
# data/samples\175test_groundtruth_.png
# data/samples\176train_input_.png
# data/samples\176train_groundtruth_.png
# Train - Discriminator Loss: 0.0774 Generator Loss: 1.1134
# data/samples\176test_input_.png
# data/samples\176test_groundtruth_.png
# data/samples\177train_input_.png
# data/samples\177train_groundtruth_.png
# Train - Discriminator Loss: 0.0775 Generator Loss: 1.1321
# data/samples\177test_input_.png
# data/samples\177test_groundtruth_.png
# data/samples\178train_input_.png
# data/samples\178train_groundtruth_.png
# Train - Discriminator Loss: 0.0776 Generator Loss: 1.1251
# data/samples\178test_input_.png
# data/samples\178test_groundtruth_.png
# data/samples\179train_input_.png
# data/samples\179train_groundtruth_.png
# Train - Discriminator Loss: 0.0747 Generator Loss: 1.1442
# data/samples\179test_input_.png
# data/samples\179test_groundtruth_.png
# data/samples\180train_input_.png
# data/samples\180train_groundtruth_.png
# Train - Discriminator Loss: 0.0732 Generator Loss: 1.1366
# data/samples\180test_input_.png
# data/samples\180test_groundtruth_.png
# data/samples\181train_input_.png
# data/samples\181train_groundtruth_.png
# Train - Discriminator Loss: 0.0705 Generator Loss: 1.1440
# Saved Model
# data/samples\181test_input_.png
# data/samples\181test_groundtruth_.png
# data/samples\182train_input_.png
# data/samples\182train_groundtruth_.png
# Train - Discriminator Loss: 0.0680 Generator Loss: 1.1547
# data/samples\182test_input_.png
# data/samples\182test_groundtruth_.png
# data/samples\183train_input_.png
# data/samples\183train_groundtruth_.png
# Train - Discriminator Loss: 0.0673 Generator Loss: 1.1469
# data/samples\183test_input_.png
# data/samples\183test_groundtruth_.png
# data/samples\184train_input_.png
# data/samples\184train_groundtruth_.png
# Train - Discriminator Loss: 0.0659 Generator Loss: 1.1585
# data/samples\184test_input_.png
# data/samples\184test_groundtruth_.png
# data/samples\185train_input_.png
# data/samples\185train_groundtruth_.png
# Train - Discriminator Loss: 0.0657 Generator Loss: 1.1425
# data/samples\185test_input_.png
# data/samples\185test_groundtruth_.png
# data/samples\186train_input_.png
# data/samples\186train_groundtruth_.png
# Train - Discriminator Loss: 0.0650 Generator Loss: 1.1377
# data/samples\186test_input_.png
# data/samples\186test_groundtruth_.png
# data/samples\187train_input_.png
# data/samples\187train_groundtruth_.png
# Train - Discriminator Loss: 0.0633 Generator Loss: 1.1597
# data/samples\187test_input_.png
# data/samples\187test_groundtruth_.png
# data/samples\188train_input_.png
# data/samples\188train_groundtruth_.png
# Train - Discriminator Loss: 0.0613 Generator Loss: 1.1557
# data/samples\188test_input_.png
# data/samples\188test_groundtruth_.png
# data/samples\189train_input_.png
# data/samples\189train_groundtruth_.png
# Train - Discriminator Loss: 0.0576 Generator Loss: 1.1678
# data/samples\189test_input_.png
# data/samples\189test_groundtruth_.png
# data/samples\190train_input_.png
# data/samples\190train_groundtruth_.png
# Train - Discriminator Loss: 0.0571 Generator Loss: 1.1749
# data/samples\190test_input_.png
# data/samples\190test_groundtruth_.png
# data/samples\191train_input_.png
# data/samples\191train_groundtruth_.png
# Train - Discriminator Loss: 0.0554 Generator Loss: 1.1560
# Saved Model
# data/samples\191test_input_.png
# data/samples\191test_groundtruth_.png
# data/samples\192train_input_.png
# data/samples\192train_groundtruth_.png
# Train - Discriminator Loss: 0.0550 Generator Loss: 1.1542
# data/samples\192test_input_.png
# data/samples\192test_groundtruth_.png
# data/samples\193train_input_.png
# data/samples\193train_groundtruth_.png
# Train - Discriminator Loss: 0.0531 Generator Loss: 1.1623
# data/samples\193test_input_.png
# data/samples\193test_groundtruth_.png
# data/samples\194train_input_.png
# data/samples\194train_groundtruth_.png
# Train - Discriminator Loss: 0.0503 Generator Loss: 1.1669
# data/samples\194test_input_.png
# data/samples\194test_groundtruth_.png
# data/samples\195train_input_.png
# data/samples\195train_groundtruth_.png
# Train - Discriminator Loss: 0.0484 Generator Loss: 1.1741
# data/samples\195test_input_.png
# data/samples\195test_groundtruth_.png
# data/samples\196train_input_.png
# data/samples\196train_groundtruth_.png
# Train - Discriminator Loss: 0.0480 Generator Loss: 1.1818
# data/samples\196test_input_.png
# data/samples\196test_groundtruth_.png
# data/samples\197train_input_.png
# data/samples\197train_groundtruth_.png
# Train - Discriminator Loss: 0.0474 Generator Loss: 1.1918
# data/samples\197test_input_.png
# data/samples\197test_groundtruth_.png
# data/samples\198train_input_.png
# data/samples\198train_groundtruth_.png
# Train - Discriminator Loss: 0.0466 Generator Loss: 1.1555
# data/samples\198test_input_.png
# data/samples\198test_groundtruth_.png
# data/samples\199train_input_.png
# data/samples\199train_groundtruth_.png
# Train - Discriminator Loss: 0.0425 Generator Loss: 1.1948
# data/samples\199test_input_.png
# data/samples\199test_groundtruth_.png
# data/samples\200train_input_.png
# data/samples\200train_groundtruth_.png
# Train - Discriminator Loss: 0.0410 Generator Loss: 1.1853
# data/samples\200test_input_.png
# data/samples\200test_groundtruth_.png
# data/samples\201train_input_.png
# data/samples\201train_groundtruth_.png
# Train - Discriminator Loss: 0.0404 Generator Loss: 1.1829
# Saved Model
# data/samples\201test_input_.png
# data/samples\201test_groundtruth_.png
# data/samples\202train_input_.png
# data/samples\202train_groundtruth_.png
# Train - Discriminator Loss: 0.0390 Generator Loss: 1.1727
# data/samples\202test_input_.png
# data/samples\202test_groundtruth_.png
# data/samples\203train_input_.png
# data/samples\203train_groundtruth_.png
# Train - Discriminator Loss: 0.0382 Generator Loss: 1.1741
# data/samples\203test_input_.png
# data/samples\203test_groundtruth_.png
# data/samples\204train_input_.png
# data/samples\204train_groundtruth_.png
# Train - Discriminator Loss: 0.0383 Generator Loss: 1.1692
# data/samples\204test_input_.png
# data/samples\204test_groundtruth_.png
# data/samples\205train_input_.png
# data/samples\205train_groundtruth_.png
# Train - Discriminator Loss: 0.0340 Generator Loss: 1.1986
# data/samples\205test_input_.png
# data/samples\205test_groundtruth_.png
# data/samples\206train_input_.png
# data/samples\206train_groundtruth_.png
# Train - Discriminator Loss: 0.0333 Generator Loss: 1.1946
# data/samples\206test_input_.png
# data/samples\206test_groundtruth_.png
# data/samples\207train_input_.png
# data/samples\207train_groundtruth_.png
# Train - Discriminator Loss: 0.0304 Generator Loss: 1.2016
# data/samples\207test_input_.png
# data/samples\207test_groundtruth_.png
# data/samples\208train_input_.png
# data/samples\208train_groundtruth_.png
# Train - Discriminator Loss: 0.0312 Generator Loss: 1.1839
# data/samples\208test_input_.png
# data/samples\208test_groundtruth_.png
# data/samples\209train_input_.png
# data/samples\209train_groundtruth_.png
# Train - Discriminator Loss: 0.0291 Generator Loss: 1.1861
# data/samples\209test_input_.png
# data/samples\209test_groundtruth_.png
# data/samples\210train_input_.png
# data/samples\210train_groundtruth_.png
# Train - Discriminator Loss: 0.0278 Generator Loss: 1.1913
# data/samples\210test_input_.png
# data/samples\210test_groundtruth_.png
# data/samples\211train_input_.png
# data/samples\211train_groundtruth_.png
# Train - Discriminator Loss: 0.0272 Generator Loss: 1.2022
# Saved Model
# data/samples\211test_input_.png
# data/samples\211test_groundtruth_.png
# data/samples\212train_input_.png
# data/samples\212train_groundtruth_.png
# Train - Discriminator Loss: 0.0262 Generator Loss: 1.1924
# data/samples\212test_input_.png
# data/samples\212test_groundtruth_.png
# data/samples\213train_input_.png
# data/samples\213train_groundtruth_.png
# Train - Discriminator Loss: 0.0239 Generator Loss: 1.2220
# data/samples\213test_input_.png
# data/samples\213test_groundtruth_.png
# data/samples\214train_input_.png
# data/samples\214train_groundtruth_.png
# Train - Discriminator Loss: 0.0235 Generator Loss: 1.1972
# data/samples\214test_input_.png
# data/samples\214test_groundtruth_.png
# data/samples\215train_input_.png
# data/samples\215train_groundtruth_.png
# Train - Discriminator Loss: 0.0229 Generator Loss: 1.2021
# data/samples\215test_input_.png
# data/samples\215test_groundtruth_.png
# data/samples\216train_input_.png
# data/samples\216train_groundtruth_.png
# Train - Discriminator Loss: 0.0213 Generator Loss: 1.1905
# data/samples\216test_input_.png
# data/samples\216test_groundtruth_.png
# data/samples\217train_input_.png
# data/samples\217train_groundtruth_.png
# Train - Discriminator Loss: 0.0218 Generator Loss: 1.1935
# data/samples\217test_input_.png
# data/samples\217test_groundtruth_.png
# data/samples\218train_input_.png
# data/samples\218train_groundtruth_.png
# Train - Discriminator Loss: 0.0185 Generator Loss: 1.2051
# data/samples\218test_input_.png
# data/samples\218test_groundtruth_.png
# data/samples\219train_input_.png
# data/samples\219train_groundtruth_.png
# Train - Discriminator Loss: 0.0204 Generator Loss: 1.1855
# data/samples\219test_input_.png
# data/samples\219test_groundtruth_.png
# data/samples\220train_input_.png
# data/samples\220train_groundtruth_.png
# Train - Discriminator Loss: 0.0190 Generator Loss: 1.2122
# data/samples\220test_input_.png
# data/samples\220test_groundtruth_.png
# data/samples\221train_input_.png
# data/samples\221train_groundtruth_.png
# Train - Discriminator Loss: 0.0175 Generator Loss: 1.1901
# Saved Model
# data/samples\221test_input_.png
# data/samples\221test_groundtruth_.png
# data/samples\222train_input_.png
# data/samples\222train_groundtruth_.png
# Train - Discriminator Loss: 0.0157 Generator Loss: 1.2221
# data/samples\222test_input_.png
# data/samples\222test_groundtruth_.png
# data/samples\223train_input_.png
# data/samples\223train_groundtruth_.png
# Train - Discriminator Loss: 0.0143 Generator Loss: 1.2056
# data/samples\223test_input_.png
# data/samples\223test_groundtruth_.png
# data/samples\224train_input_.png
# data/samples\224train_groundtruth_.png
# Train - Discriminator Loss: 0.0149 Generator Loss: 1.1941
# data/samples\224test_input_.png
# data/samples\224test_groundtruth_.png
# data/samples\225train_input_.png
# data/samples\225train_groundtruth_.png
# Train - Discriminator Loss: 0.0151 Generator Loss: 1.2142
# data/samples\225test_input_.png
# data/samples\225test_groundtruth_.png
# data/samples\226train_input_.png
# data/samples\226train_groundtruth_.png
# Train - Discriminator Loss: 0.0135 Generator Loss: 1.2115
# data/samples\226test_input_.png
# data/samples\226test_groundtruth_.png
# data/samples\227train_input_.png
# data/samples\227train_groundtruth_.png
# Train - Discriminator Loss: 0.0136 Generator Loss: 1.1970
# data/samples\227test_input_.png
# data/samples\227test_groundtruth_.png
# data/samples\228train_input_.png
# data/samples\228train_groundtruth_.png
# Train - Discriminator Loss: 0.0124 Generator Loss: 1.2009
# data/samples\228test_input_.png
# data/samples\228test_groundtruth_.png
# data/samples\229train_input_.png
# data/samples\229train_groundtruth_.png
# Train - Discriminator Loss: 0.0121 Generator Loss: 1.2093
# data/samples\229test_input_.png
# data/samples\229test_groundtruth_.png
# data/samples\230train_input_.png
# data/samples\230train_groundtruth_.png
# Train - Discriminator Loss: 0.0106 Generator Loss: 1.2195
# data/samples\230test_input_.png
# data/samples\230test_groundtruth_.png
# data/samples\231train_input_.png
# data/samples\231train_groundtruth_.png
# Train - Discriminator Loss: 0.0094 Generator Loss: 1.1985
# Saved Model
# data/samples\231test_input_.png
# data/samples\231test_groundtruth_.png
# data/samples\232train_input_.png
# data/samples\232train_groundtruth_.png
# Train - Discriminator Loss: 0.0109 Generator Loss: 1.1916
# data/samples\232test_input_.png
# data/samples\232test_groundtruth_.png
# data/samples\233train_input_.png
# data/samples\233train_groundtruth_.png
# Train - Discriminator Loss: 0.0107 Generator Loss: 1.2263
# data/samples\233test_input_.png
# data/samples\233test_groundtruth_.png
# data/samples\234train_input_.png
# data/samples\234train_groundtruth_.png
# Train - Discriminator Loss: 0.0089 Generator Loss: 1.2160
# data/samples\234test_input_.png
# data/samples\234test_groundtruth_.png
# data/samples\235train_input_.png
# data/samples\235train_groundtruth_.png
# Train - Discriminator Loss: 0.0078 Generator Loss: 1.2215
# data/samples\235test_input_.png
# data/samples\235test_groundtruth_.png
# data/samples\236train_input_.png
# data/samples\236train_groundtruth_.png
# Train - Discriminator Loss: 0.0077 Generator Loss: 1.2178
# data/samples\236test_input_.png
# data/samples\236test_groundtruth_.png
# data/samples\237train_input_.png
# data/samples\237train_groundtruth_.png
# Train - Discriminator Loss: 0.0083 Generator Loss: 1.1841
# data/samples\237test_input_.png
# data/samples\237test_groundtruth_.png
# data/samples\238train_input_.png
# data/samples\238train_groundtruth_.png
# Train - Discriminator Loss: 0.0073 Generator Loss: 1.2002
# data/samples\238test_input_.png
# data/samples\238test_groundtruth_.png
# data/samples\239train_input_.png
# data/samples\239train_groundtruth_.png
# Train - Discriminator Loss: 0.0064 Generator Loss: 1.1892
# data/samples\239test_input_.png
# data/samples\239test_groundtruth_.png
# data/samples\240train_input_.png
# data/samples\240train_groundtruth_.png
# Train - Discriminator Loss: 0.0061 Generator Loss: 1.2120
# data/samples\240test_input_.png
# data/samples\240test_groundtruth_.png
# data/samples\241train_input_.png
# data/samples\241train_groundtruth_.png
# Train - Discriminator Loss: 0.0061 Generator Loss: 1.2050
# Saved Model
# data/samples\241test_input_.png
# data/samples\241test_groundtruth_.png
# data/samples\242train_input_.png
# data/samples\242train_groundtruth_.png
# Train - Discriminator Loss: 0.0052 Generator Loss: 1.2034
# data/samples\242test_input_.png
# data/samples\242test_groundtruth_.png
# data/samples\243train_input_.png
# data/samples\243train_groundtruth_.png
# Train - Discriminator Loss: 0.0052 Generator Loss: 1.2239
# data/samples\243test_input_.png
# data/samples\243test_groundtruth_.png
# data/samples\244train_input_.png
# data/samples\244train_groundtruth_.png
# Train - Discriminator Loss: 0.0051 Generator Loss: 1.1950
# data/samples\244test_input_.png
# data/samples\244test_groundtruth_.png
# data/samples\245train_input_.png
# data/samples\245train_groundtruth_.png
# Train - Discriminator Loss: 0.0064 Generator Loss: 1.2116
# data/samples\245test_input_.png
# data/samples\245test_groundtruth_.png
# data/samples\246train_input_.png
# data/samples\246train_groundtruth_.png
# Train - Discriminator Loss: 0.0045 Generator Loss: 1.2115
# data/samples\246test_input_.png
# data/samples\246test_groundtruth_.png
# data/samples\247train_input_.png
# data/samples\247train_groundtruth_.png
# Train - Discriminator Loss: 0.0047 Generator Loss: 1.2162
# data/samples\247test_input_.png
# data/samples\247test_groundtruth_.png
# data/samples\248train_input_.png
# data/samples\248train_groundtruth_.png
# Train - Discriminator Loss: 0.0047 Generator Loss: 1.2098
# data/samples\248test_input_.png
# data/samples\248test_groundtruth_.png
# data/samples\249train_input_.png
# data/samples\249train_groundtruth_.png
# Train - Discriminator Loss: 0.0040 Generator Loss: 1.2166
# data/samples\249test_input_.png
# data/samples\249test_groundtruth_.png
# data/samples\250train_input_.png
# data/samples\250train_groundtruth_.png
# Train - Discriminator Loss: 0.0036 Generator Loss: 1.1910
# data/samples\250test_input_.png
# data/samples\250test_groundtruth_.png
# data/samples\251train_input_.png
# data/samples\251train_groundtruth_.png
# Train - Discriminator Loss: 0.0039 Generator Loss: 1.2328
# Saved Model
# data/samples\251test_input_.png
# data/samples\251test_groundtruth_.png
# data/samples\252train_input_.png
# data/samples\252train_groundtruth_.png
# Train - Discriminator Loss: 0.0029 Generator Loss: 1.2113
# data/samples\252test_input_.png
# data/samples\252test_groundtruth_.png
# data/samples\253train_input_.png
# data/samples\253train_groundtruth_.png
# Train - Discriminator Loss: 0.0037 Generator Loss: 1.2056
# data/samples\253test_input_.png
# data/samples\253test_groundtruth_.png
# data/samples\254train_input_.png
# data/samples\254train_groundtruth_.png
# Train - Discriminator Loss: 0.0036 Generator Loss: 1.1952
# data/samples\254test_input_.png
# data/samples\254test_groundtruth_.png
# data/samples\255train_input_.png
# data/samples\255train_groundtruth_.png
# Train - Discriminator Loss: 0.0030 Generator Loss: 1.1963
# data/samples\255test_input_.png
# data/samples\255test_groundtruth_.png
# data/samples\256train_input_.png
# data/samples\256train_groundtruth_.png
# Train - Discriminator Loss: 0.0029 Generator Loss: 1.2184
# data/samples\256test_input_.png
# data/samples\256test_groundtruth_.png
# data/samples\257train_input_.png
# data/samples\257train_groundtruth_.png
# Train - Discriminator Loss: 0.0032 Generator Loss: 1.2001
# data/samples\257test_input_.png
# data/samples\257test_groundtruth_.png
# data/samples\258train_input_.png
# data/samples\258train_groundtruth_.png
# Train - Discriminator Loss: 0.0025 Generator Loss: 1.2147
# data/samples\258test_input_.png
# data/samples\258test_groundtruth_.png
# data/samples\259train_input_.png
# data/samples\259train_groundtruth_.png
# Train - Discriminator Loss: 0.0025 Generator Loss: 1.2028
# data/samples\259test_input_.png
# data/samples\259test_groundtruth_.png
# data/samples\260train_input_.png
# data/samples\260train_groundtruth_.png
# Train - Discriminator Loss: 0.0030 Generator Loss: 1.2029
# data/samples\260test_input_.png
# data/samples\260test_groundtruth_.png
# data/samples\261train_input_.png
# data/samples\261train_groundtruth_.png
# Train - Discriminator Loss: 0.0027 Generator Loss: 1.1967
# Saved Model
# data/samples\261test_input_.png
# data/samples\261test_groundtruth_.png
# data/samples\262train_input_.png
# data/samples\262train_groundtruth_.png
# Train - Discriminator Loss: 0.0029 Generator Loss: 1.2009
# data/samples\262test_input_.png
# data/samples\262test_groundtruth_.png
# data/samples\263train_input_.png
# data/samples\263train_groundtruth_.png
# Train - Discriminator Loss: 0.0018 Generator Loss: 1.1960
# data/samples\263test_input_.png
# data/samples\263test_groundtruth_.png
# data/samples\264train_input_.png
# data/samples\264train_groundtruth_.png
# Train - Discriminator Loss: 0.0023 Generator Loss: 1.2085
# data/samples\264test_input_.png
# data/samples\264test_groundtruth_.png
# data/samples\265train_input_.png
# data/samples\265train_groundtruth_.png
# Train - Discriminator Loss: 0.0023 Generator Loss: 1.2098
# data/samples\265test_input_.png
# data/samples\265test_groundtruth_.png
# data/samples\266train_input_.png
# data/samples\266train_groundtruth_.png
# Train - Discriminator Loss: 0.0018 Generator Loss: 1.2093
# data/samples\266test_input_.png
# data/samples\266test_groundtruth_.png
# data/samples\267train_input_.png
# data/samples\267train_groundtruth_.png
# Train - Discriminator Loss: 0.0024 Generator Loss: 1.1921
# data/samples\267test_input_.png
# data/samples\267test_groundtruth_.png
# data/samples\268train_input_.png
# data/samples\268train_groundtruth_.png
# Train - Discriminator Loss: 0.0015 Generator Loss: 1.1982
# data/samples\268test_input_.png
# data/samples\268test_groundtruth_.png
# data/samples\269train_input_.png
# data/samples\269train_groundtruth_.png
# Train - Discriminator Loss: 0.0014 Generator Loss: 1.2184
# data/samples\269test_input_.png
# data/samples\269test_groundtruth_.png
# data/samples\270train_input_.png
# data/samples\270train_groundtruth_.png
# Train - Discriminator Loss: 0.0013 Generator Loss: 1.2021
# data/samples\270test_input_.png
# data/samples\270test_groundtruth_.png
# data/samples\271train_input_.png
# data/samples\271train_groundtruth_.png
# Train - Discriminator Loss: 0.0036 Generator Loss: 1.1914
# Saved Model
# data/samples\271test_input_.png
# data/samples\271test_groundtruth_.png
# data/samples\272train_input_.png
# data/samples\272train_groundtruth_.png
# Train - Discriminator Loss: 0.0019 Generator Loss: 1.2198
# data/samples\272test_input_.png
# data/samples\272test_groundtruth_.png
# data/samples\273train_input_.png
# data/samples\273train_groundtruth_.png
# Train - Discriminator Loss: 0.0011 Generator Loss: 1.2020
# data/samples\273test_input_.png
# data/samples\273test_groundtruth_.png
# data/samples\274train_input_.png
# data/samples\274train_groundtruth_.png
# Train - Discriminator Loss: 0.0017 Generator Loss: 1.1875
# data/samples\274test_input_.png
# data/samples\274test_groundtruth_.png
# data/samples\275train_input_.png
# data/samples\275train_groundtruth_.png
# Train - Discriminator Loss: 0.0017 Generator Loss: 1.2008
# data/samples\275test_input_.png
# data/samples\275test_groundtruth_.png
# data/samples\276train_input_.png
# data/samples\276train_groundtruth_.png
# Train - Discriminator Loss: 0.0011 Generator Loss: 1.2066
# data/samples\276test_input_.png
# data/samples\276test_groundtruth_.png
# data/samples\277train_input_.png
# data/samples\277train_groundtruth_.png
# Train - Discriminator Loss: 0.0010 Generator Loss: 1.1996
# data/samples\277test_input_.png
# data/samples\277test_groundtruth_.png
# data/samples\278train_input_.png
# data/samples\278train_groundtruth_.png
# Train - Discriminator Loss: 0.0010 Generator Loss: 1.2063
# data/samples\278test_input_.png
# data/samples\278test_groundtruth_.png
# data/samples\279train_input_.png
# data/samples\279train_groundtruth_.png
# Train - Discriminator Loss: 0.0009 Generator Loss: 1.1983
# data/samples\279test_input_.png
# data/samples\279test_groundtruth_.png
# data/samples\280train_input_.png
# data/samples\280train_groundtruth_.png
# Train - Discriminator Loss: 0.0008 Generator Loss: 1.2020
# data/samples\280test_input_.png
# data/samples\280test_groundtruth_.png
# data/samples\281train_input_.png
# data/samples\281train_groundtruth_.png
# Train - Discriminator Loss: 0.0010 Generator Loss: 1.2161
# Saved Model
# data/samples\281test_input_.png
# data/samples\281test_groundtruth_.png
# data/samples\282train_input_.png
# data/samples\282train_groundtruth_.png
# Train - Discriminator Loss: 0.0013 Generator Loss: 1.2122
# data/samples\282test_input_.png
# data/samples\282test_groundtruth_.png
# data/samples\283train_input_.png
# data/samples\283train_groundtruth_.png
# Train - Discriminator Loss: 0.0009 Generator Loss: 1.1955
# data/samples\283test_input_.png
# data/samples\283test_groundtruth_.png
# data/samples\284train_input_.png
# data/samples\284train_groundtruth_.png
# Train - Discriminator Loss: 0.0008 Generator Loss: 1.2117
# data/samples\284test_input_.png
# data/samples\284test_groundtruth_.png
# data/samples\285train_input_.png
# data/samples\285train_groundtruth_.png
# Train - Discriminator Loss: 0.0010 Generator Loss: 1.1994
# data/samples\285test_input_.png
# data/samples\285test_groundtruth_.png
# data/samples\286train_input_.png
# data/samples\286train_groundtruth_.png
# Train - Discriminator Loss: 0.0009 Generator Loss: 1.1883
# data/samples\286test_input_.png
# data/samples\286test_groundtruth_.png
# data/samples\287train_input_.png
# data/samples\287train_groundtruth_.png
# Train - Discriminator Loss: 0.0010 Generator Loss: 1.1914
# data/samples\287test_input_.png
# data/samples\287test_groundtruth_.png
# data/samples\288train_input_.png
# data/samples\288train_groundtruth_.png
# Train - Discriminator Loss: 0.0008 Generator Loss: 1.1897
# data/samples\288test_input_.png
# data/samples\288test_groundtruth_.png
# data/samples\289train_input_.png
# data/samples\289train_groundtruth_.png
# Train - Discriminator Loss: 0.0009 Generator Loss: 1.2151
# data/samples\289test_input_.png
# data/samples\289test_groundtruth_.png
# data/samples\290train_input_.png
# data/samples\290train_groundtruth_.png
# Train - Discriminator Loss: 0.0006 Generator Loss: 1.1869
# data/samples\290test_input_.png
# data/samples\290test_groundtruth_.png
# data/samples\291train_input_.png
# data/samples\291train_groundtruth_.png
# Train - Discriminator Loss: 0.0013 Generator Loss: 1.1989
# Saved Model
# data/samples\291test_input_.png
# data/samples\291test_groundtruth_.png
# data/samples\292train_input_.png
# data/samples\292train_groundtruth_.png
# Train - Discriminator Loss: 0.0006 Generator Loss: 1.1877
# data/samples\292test_input_.png
# data/samples\292test_groundtruth_.png
# data/samples\293train_input_.png
# data/samples\293train_groundtruth_.png
# Train - Discriminator Loss: 0.0006 Generator Loss: 1.2002
# data/samples\293test_input_.png
# data/samples\293test_groundtruth_.png
# data/samples\294train_input_.png
# data/samples\294train_groundtruth_.png
# Train - Discriminator Loss: 0.0007 Generator Loss: 1.2205
# data/samples\294test_input_.png
# data/samples\294test_groundtruth_.png
# data/samples\295train_input_.png
# data/samples\295train_groundtruth_.png
# Train - Discriminator Loss: 0.0011 Generator Loss: 1.1972
# data/samples\295test_input_.png
# data/samples\295test_groundtruth_.png
# data/samples\296train_input_.png
# data/samples\296train_groundtruth_.png
# Train - Discriminator Loss: 0.0005 Generator Loss: 1.1988
# data/samples\296test_input_.png
# data/samples\296test_groundtruth_.png
# data/samples\297train_input_.png
# data/samples\297train_groundtruth_.png
# Train - Discriminator Loss: 0.0006 Generator Loss: 1.2076
# data/samples\297test_input_.png
# data/samples\297test_groundtruth_.png
# data/samples\298train_input_.png
# data/samples\298train_groundtruth_.png
# Train - Discriminator Loss: 0.0020 Generator Loss: 1.2255
# data/samples\298test_input_.png
# data/samples\298test_groundtruth_.png
# data/samples\299train_input_.png
# data/samples\299train_groundtruth_.png
# Train - Discriminator Loss: 0.0005 Generator Loss: 1.1839
# data/samples\299test_input_.png
# data/samples\299test_groundtruth_.png
# data/samples\300train_input_.png
# data/samples\300train_groundtruth_.png
# Train - Discriminator Loss: 0.0005 Generator Loss: 1.1928
# Saved Model
# data/samples\300test_input_.png
# data/samples\300test_groundtruth_.png
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# colorful_world.models.c_ganLoss.cGANLoss

# %%
gen_model_cpu = cgan.gen_model.cpu()
torch.save(
    gen_model_cpu, 
    os.path.join(
        '/content/gdrive',"My Drive","pix2pix","first_pass", "gen_model_epoch_30_cpu"
    )
)

# %% [markdown]
# _Note to myself: Other commands_

# %%
# %rm -rf colorful-world-pix2pix/

# %%
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl 
# !pip3 install torchvision

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

# %%
from torch import optim
cgan = cGAN(config=config)

cgan.dis_model = torch.load(
    os.path.join(
        '/content/gdrive',"My Drive","pix2pix","first_pass", 'dis_model_59.pk'
      )
) 

cgan.gen_model = torch.load(
    os.path.join(
        '/content/gdrive',"My Drive","pix2pix","first_pass", 'gen_model_59.pk'
      )
)

cgan.optimizer_dis = optim.Adam(cgan.dis_model.parameters(), lr=cgan.config.lr_dis)
cgan.optimizer_gen = optim.Adam(cgan.gen_model.parameters(), lr=cgan.config.lr_gen)

# %%
res = cgan.predict()
res[1].save("img.png",format="PNG")

# %%
cgan.config.prediction_dir = "/content/colorful-world-pix2pix/colorful_world/data/test"
cgan.data_init()
res = cgan.predict()
